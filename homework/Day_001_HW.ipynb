# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
# %config IPCompleter.greedy=True
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(A, B):
    """
    請完成這個 Function 後往下執行
    """
    return np.square(A-B).mean()
    

def  mean_absolute_error (A, B):
    return np.sum(np.abs(A-B)).mean()

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 250.677
# The Mean absolute error is 1278.085

# %% [markdown]
# 作業1：
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# Mobile phone activity in a city (https://www.kaggle.com/marcodena/mobile-phone-activity)
#
# 1. 你選的這組資料為何重要
# 手機使用已成為每個人生活的一部分，生活中大大小小的事情都環繞著手機進行，除了透過手機和網際網路活動了解特定區域使用者行為和移動，用以改善電信網路以改善運營商營運和投資成本、設計不同資費方案和地區化客制商品增加運營商營收
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# 提供者為義大利電信公司，收集一周間米蘭和Trentino省所有基站(Radio Base Station)的Call Details Records(CDRs)，其中包含簡訊、語音和網際網路活動資訊。
# 此份資料也與天氣、電力使用、新聞事件與tweets 整合，用以發展跨領域模型
#
# 3. 蒐集而來的資料型態為何
# 資料已經整理為 CSV 格式，基站編號 (Cell ID) 也轉換為地理位置，資料按照每天一個檔案，檔案包含特定區域每小時電話活動次數
#
# 4. 這組資料想解決的問題如何評估
# 透過年度財報資支出與營收比較歷年變化

# %%
作業2：

想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：

1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
業績提升重點方向非收入上升而是利潤上升，希望藉由回頭客產生更多固定收入，而持續透過補貼或促銷僅使車隊規模變大

2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
> 透過貼在後座 QR Code方便客戶使用手機至網站上填寫問卷，客戶填寫問卷可獲得折扣方式，增加客戶填寫意願
> 客戶問卷收集: 載客時間、載客地點、起訖地點、移動時間、金額、滿意度、本周內是否曾乘坐

3. 蒐集而來的資料型態為何
> 問卷網站的資料庫

4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
依照地點與時間，計算收入比例 (金額/距離/時間)、滿意度、本周內是否曾乘坐三者間關係，需要證明重覆乘坐滿意度有關連性，滿意度與收入有關連性
