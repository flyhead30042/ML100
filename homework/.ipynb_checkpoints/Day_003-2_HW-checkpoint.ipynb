# %% [markdown]
# ## 讀取 txt 檔
# * 請讀取 [text file](https://raw.githubusercontent.com/vashineyu/slides_and_others/master/tutorial/examples/imagenet_urls_examples.txt)
# * 懶人複製連結: https://raw.githubusercontent.com/vashineyu/slides_and_others/master/tutorial/examples/imagenet_urls_examples.txt
#
# ### Hints: 使用 [Request](https://blog.gtwang.org/programming/python-requests-module-tutorial/) 抓取資料
# ### Hints: [字串分割](http://www.runoob.com/python/att-string-split.html)
# ### Hints: 例外處理: [Try-Except](https://pydoing.blogspot.com/2011/01/python-try.html)

# %%
# %config IPCompleter.greedy=True

# %%
## 假如我們不想把資料載到自己的電腦裡?
# 把連結填入
target_url = "https://raw.githubusercontent.com/vashineyu/slides_and_others/master/tutorial/examples/imagenet_urls_examples.txt"

# %%
import requests
response = requests.get(target_url)
data = response.text

# 用 request 傳送回來的資料不會認得斷行符號
print(len(data))
print(data[0:100])
# Out:
# 784594
# n00015388_157	http://farm1.static.flickr.com/145/430300483_21e993670c.jpg
# n00015388_238	http://farm2

# %%
# 找到換行符號，用該符號做字串分割後，把它拿掉
split_tag = ""

data2 = data.split()
print(len(data2))

for i in range(10):
    print(data2[i])
# Out:
# 20008
# n00015388_157
# http://farm1.static.flickr.com/145/430300483_21e993670c.jpg
# n00015388_238
# http://farm2.static.flickr.com/1005/3352960681_37b9c1d27b.jpg
# n00015388_304
# http://farm1.static.flickr.com/27/51009336_a9663af3dd.jpg
# n00015388_327
# http://farm4.static.flickr.com/3025/2444687979_bf7bc8df21.jpg
# n00015388_355
# http://img100.imageshack.us/img100/3253/forrest004fs9.jpg

# %% [markdown]
# ## 將 txt 轉成 pandas dataframe

# %%
import pandas as pd

data_id=[]
data_link=[]


data_id = [v for i, v in enumerate(data2) if i%2==0]
data_link = [v for i, v in enumerate(data2) if i%2==1]

# print(str(len(data_id)) + ":" + str(len(data_link)))

arrange_data = {"id":data_id, "link":data_link}
    
df = pd.DataFrame(arrange_data)
df.head()
# Out:
#               id                                               link
# 0  n00015388_157  http://farm1.static.flickr.com/145/430300483_2...
# 1  n00015388_238  http://farm2.static.flickr.com/1005/3352960681...
# 2  n00015388_304  http://farm1.static.flickr.com/27/51009336_a96...
# 3  n00015388_327  http://farm4.static.flickr.com/3025/2444687979...
# 4  n00015388_355  http://img100.imageshack.us/img100/3253/forres...

# %% [markdown]
# ## 讀取圖片，請讀取上面 data frame 中的前 5 張圖片

# %%
from PIL import Image
from io import BytesIO
import numpy as np
import matplotlib.pyplot as plt

# 請用 df.loc[...] 得到第一筆資料的連結
# first_link = df.loc[0, "link"]
# first_link = df["link"][0]
first_link = df.loc[0, ["link"]][0] 

print(first_link)

response = requests.get(first_link)
img = Image.open(BytesIO(response.content))

# Convert img to numpy array

plt.imshow(img)
plt.show()
# Out:
# http://farm1.static.flickr.com/145/430300483_21e993670c.jpg

# %%
def img2arr_fromURLs(url_list, resize = False):
    """
    請完成這個 Function
    Args
        - url_list: list of URLs
        - resize: bool
    Return
        - list of array
    """
    
    img_list = []
    for url in url_list:
        try:
            res= requests.get(url)
            img = Image.open(BytesIO(res.content))
            img_list.append(img)
        except:
            print("Fails to get {:s}".format(url))
            pass
        
    return img_list

# %%
# result = img2arr_fromURLs(df[0:5][1].values)
result = img2arr_fromURLs(df["link"][0:20])
print("Total images that we got: %i " % len(result)) # 如果不等於 5, 代表有些連結失效囉

for im_get in result:
    plt.imshow(im_get)
    plt.show()
# Out:
# Fails to get http://img100.imageshack.us/img100/3253/forrest004fs9.jpg
# Fails to get http://img172.imageshack.us/img172/4606/napo03072en9.jpg
# Fails to get http://fotootjesvanannelies.web-log.nl/olifantfotootjes/images/2008/06/04/img_8870.jpg
# Fails to get http://www.deweekkrant.nl/images/library/pictures/4f/2e/a5/cf/2_3d81b762a5e8a345bbb1f0884fab2e9762146129.jpg
# Fails to get http://www.porschemania.it/discus/messages/815/102099.jpg
# Fails to get http://www.dierentuin.nl/images/jongengiraffe.jpg
# Fails to get http://farm4.static.flickr.com/3279/3118047175_259ab89c92.jpg
# Fails to get https://w3f7yg.bay.livefilestore.com/y1miLTQmcuoRakgVwM6_bngzVE6TzzugspJiu6zK1_8F_kAD0tLiNV6nRNu9gQjci3MNbubrk3M8pSQlHpG3a8NO88Qx4dvvuugxBvdzeYg1j4KQk45GZIrKYpqxRxRMhCWK3PxXknn61E/IMG_4991斑马.jpg
# Total images that we got: 12
