# %% [markdown]
# # 作業
# ### 用 digits (dataset.load_digits()) 資料嘗試跑 t-SNE

# %%
from sklearn import datasets
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import offsetbox
from sklearn.manifold import TSNE
import pandas as pd
import seaborn as sns

digits = datasets.load_digits()
X = digits.data
y = digits.target

# %%
print(X)
print(X.shape)
print(y)
print(y.shape)
# Out:
# [[ 0.  0.  5. ...  0.  0.  0.]
#  [ 0.  0.  0. ... 10.  0.  0.]
#  [ 0.  0.  0. ... 16.  9.  0.]
#  ...
#  [ 0.  0.  1. ...  6.  0.  0.]
#  [ 0.  0.  2. ... 12.  0.  0.]
#  [ 0.  0. 10. ... 12.  1.  0.]]
# (1797, 64)
# [0 1 2 ... 8 9 8]
# (1797,)

# %%
tsne = manifold.TSNE(n_components=2, random_state=0, init='pca', learning_rate=200., early_exaggeration=12.)
newX = tsne.fit_transform(X)

# %%
print(newX)
print(newX.shape)
# Out:
# [[ -2.888679  57.7351  ]
#  [ 27.26694  -19.374847]
#  [ 18.856754  -8.129786]
#  ...
#  [  9.873543 -12.694518]
#  [-19.124634  28.904827]
#  [  2.801365  -9.643776]]
# (1797, 2)

# %%
data= np.concatenate((newX, y.reshape(-1,1)), axis=1)
df = pd.DataFrame(data, columns=["X1", "X2", "y"])
df
# Out:
#              X1         X2    y
# 0     -2.888679  57.735100  0.0
# 1     27.266939 -19.374847  1.0
# 2     18.856754  -8.129786  2.0
# 3    -42.306053  12.308002  3.0
# 4     56.142822   3.853731  4.0
# 5    -33.381535  25.748123  5.0
# 6     22.901567  19.184654  6.0
# 7     -6.364678 -55.191139  7.0
# 8      3.505238  -8.640120  8.0
# 9    -16.723423  28.823910  9.0
# 10     0.514631  54.974567  0.0
# 11    31.910057  -8.080958  1.0
# 12   -39.200542 -25.774199  2.0
# 13   -49.601181   5.534387  3.0
# 14    58.570202  -1.808749  4.0
# 15   -19.605286  -5.109249  5.0
# 16    21.739624  25.044413  6.0
# 17     2.414289 -52.280964  7.0
# 18     5.145144 -18.868008  8.0
# 19   -32.655724  22.758516  9.0
# 20     6.768155  53.572937  0.0
# 21    33.250076 -10.967830  1.0
# 22   -40.048111 -29.858568  2.0
# 23   -50.355724  -0.774996  3.0
# 24    54.698936   2.525554  4.0
# 25   -23.635448  -7.170804  5.0
# 26    23.596516  18.557468  6.0
# 27     8.515463 -53.322033  7.0
# 28     4.754815 -14.413892  8.0
# 29   -32.942070  23.438667  9.0
# ...         ...        ...  ...
# 1767  56.261230   1.452437  4.0
# 1768  10.135996  54.614944  0.0
# 1769 -15.012848   9.435560  5.0
# 1770 -45.768894   5.707229  3.0
# 1771  22.185080  19.509209  6.0
# 1772 -21.598272  27.604250  9.0
# 1773  29.496754  29.046949  6.0
# 1774  16.574293 -17.407654  1.0
# 1775  -7.074551 -59.408905  7.0
# 1776 -13.072138   5.628240  5.0
# 1777  56.162609   3.817409  4.0
# 1778  60.281940   5.479793  4.0
# 1779   4.436430 -54.844509  7.0
# 1780 -34.650585 -25.147404  2.0
# 1781   3.274397 -10.946951  8.0
# 1782 -34.796600 -26.886177  2.0
# 1783 -32.147110 -26.549414  2.0
# 1784 -11.385889   5.907611  5.0
# 1785  -0.985991 -60.621151  7.0
# 1786 -32.499798  26.807592  9.0
# 1787 -14.199841   9.719745  5.0
# 1788  59.470612   4.392191  4.0
# 1789  13.292128 -16.566954  8.0
# 1790  20.009975 -15.867823  8.0
# 1791  60.671959   1.399068  4.0
# 1792 -25.984743  30.909403  9.0
# 1793   3.832958  51.121704  0.0
# 1794   9.873543 -12.694518  8.0
# 1795 -19.124634  28.904827  9.0
# 1796   2.801365  -9.643776  8.0
#
# [1797 rows x 3 columns]

# %%
plt.figure(figsize=(10,5))
sns.set(style="whitegrid")
sns.scatterplot(data=df, x="X1", y="X2", hue="y", palette="Set1")
