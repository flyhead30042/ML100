# %% [markdown]
# # 作業
#
# - 作業目標 : iris (dataset.load_iris()) 資料嘗試跑 kmeans (可以測試不同的群數 , init 等)

# %%
from sklearn import datasets
from sklearn.cluster import KMeans
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt

iris = datasets.load_iris()
X = iris.data
y = iris.target

# %% [markdown]
# ### 載入 相關套件 並 執行 kmean 實驗 ...
#
# - 實驗測試不同的群數
# - 實驗測試不同的初始值
# - 呈現結果

# %%
A = [ X[:, [0,1]], X[:, [2,3]], X[:,[0,2]], X[:, [1,3]] ]

model = KMeans(n_clusters=3, init="k-means++", n_init=5, verbose=1, random_state=7, n_jobs=2)
fig, ax = plt.subplots(4,2, figsize=(15,15))

sns.scatterplot(x=A[0][:,0], y=A[0][:,1], hue= y, ax=ax[0,0])
predict_y0 = model.fit_predict(A[0])
sns.scatterplot(x=A[0][:,0], y=A[0][:,1], hue=predict_y0, ax=ax[0,1])

sns.scatterplot(x=A[1][:,0], y=A[1][:,1], hue= y, ax=ax[1,0])
predict_y1 = model.fit_predict(A[1])
sns.scatterplot(x=A[1][:,0], y=A[1][:,1], hue=predict_y1, ax=ax[1,1])

sns.scatterplot(x=A[2][:,0], y=A[2][:,1], hue= y, ax=ax[2,0])
predict_y2 = model.fit_predict(A[2])
sns.scatterplot(x=A[2][:,0], y=A[2][:,1], hue=predict_y2, ax=ax[2,1])

sns.scatterplot(x=A[3][:,0], y=A[3][:,1], hue= y, ax=ax[3,0])
predict_y3 = model.fit_predict(A[3])
sns.scatterplot(x=A[3][:,0], y=A[3][:,1], hue=predict_y3, ax=ax[3,1])
